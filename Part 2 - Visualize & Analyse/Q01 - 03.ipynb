# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size: 40px; font-weight: bold">
#         DATATHON 2026 - THE GRIDBREAKER
#     </span>
# </div>
#
# <div style="text-align: center;">
#     <span style="font-size: 32px; font-weight: bold">
#         FIRST ROUND
#     </span>
# </div>
#
# <div style="text-align: center;">
#     <span style="font-size: 24px; font-weight: bold">
#         <i>
#             Visualize & Analyse <br>
#             Q01 - Q03
#         </i>
#     </span>
# </div>
#
# <div style="text-align: right;">
#     <span style="font-size: 14px">
#         <i>
#             April 22, 2026
#         </i>
#     </span>
# </div>

# %% [markdown]
# | Name | Email |
# | --- | --- |
# | [Name] | [Email] |

# %% [markdown]
# <h1 align="center">
#     <span style="font-size: 40px; font-weight: bold">
#         Table of Content
#     </span style>
# </h1>
#
# I. [** <Header 1> **](#i)
#
# II. [** <Header 1> **](#ii)
#
# 1. [** <Header 2> **](#ii_1)
#
# 2. [** <Header 2> **](ii_2)
#
# 3. [** <Header 2> **](ii_3)
#
# 4. [** <Header 2> **](ii_4)

# %% [markdown]
# <h1 id="i" style="font-weight: bold"> Header 1 </h1>
